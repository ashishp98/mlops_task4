# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img1 = cv2.imread("cat.jpg")
img2 = cv2.imread("dog.jpg")
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
#cv2.imshow("image1",img1)
#cv2.waitKey(0) == 13
#cv2.destroyAllWindows()

# %%
plt.imshow(img1)

# %%
#cv2.imshow("image2",img2)
#cv2.waitKey(0) == 13
#cv2.destroyAllWindows()
plt.imshow(img2)

# %%
img1_array = img1.copy()
img2_array = img2.copy()

# %%
img1_array_cropped = img1_array[50:600, 400:1000]
img1_array_cropped.shape
# Out:
# (550, 600, 3)

# %%
# cv2.imshow("CROPPED", img1_array_cropped)
# cv2.waitKey(0) == 13
# cv2.destroyAllWindows()
plt.imshow(img1_array_cropped)
cv2.imwrite("image1.jpg",img1_array_cropped)
# Out:
# True

# %%
img2_array_cropped = img2_array[50:600, 150:750]
img2_array_cropped.shape
# Out:
# (550, 600, 3)

# %%
# cv2.imshow("CROPPED", img2_array_cropped)
# cv2.waitKey(0) == 13
# cv2.destroyAllWindows()
plt.imshow(img2_array_cropped)
cv2.imwrite("image2.jpg",img2_array_cropped)
# Out:
# True

# %%
img1[50:600, 150:750] = img2_array_cropped

# %%
# cv2.imshow("CROPPED", img1)
# cv2.waitKey(0) == 13
# cv2.destroyAllWindows()
plt.imshow(img1)

# %%
img2[50:600, 100:700] = img1_array_cropped

# %%
# cv2.imshow("CROPPED", img2)
# cv2.waitKey(0) == 13
# cv2.destroyAllWindows()
plt.imshow(img2)
